# %% [markdown]
# ## Credit Risk Scoring With ML

# %% [markdown]
# ### 1- Loading the data first

# %%
#!pip install numpy==1.26.4

#!pip install matplotlib==3.9.2

#!pip install --upgrade matplotlib 



# !pip uninstall matplotlib

#!pip install matplotlib --upgrade
# Out:
# ^C

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11400\322768712.py in <module>
# ----> 1 import matplotlib.pyplot as plt
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in <module>
#     969 # triggering resolution of _auto_backend_sentinel.
#     970 rcParamsDefault = _rc_params_in_file(
# --> 971     cbook._get_data_path("matplotlibrc"),
#     972     # Strip leading comment.
#     973     transform=lambda line: line[1:] if line.startswith("#") else line,
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\cbook\__init__.py in _get_data_path(*args)
#
# AttributeError: module 'matplotlib' has no attribute 'get_data_path'
